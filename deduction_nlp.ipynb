# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikabesi/NLP_LAB/blob/main/deduction_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
facts = {
    "Socrates": "human",
    "Plato": "human"
}

rules = {
    "human": "mortal"
}

def deduce(entity):
    if entity in facts:
        fact = facts[entity]
        if fact in rules:
            return f"{entity} is {rules[fact]}"
    return f"No deduction for {entity}"

print(deduce("Socrates"))
print(deduce("Plato"))
print(deduce("Zeus"))
# Out:
# Socrates is mortal
# Plato is mortal
# No deduction for Zeus
