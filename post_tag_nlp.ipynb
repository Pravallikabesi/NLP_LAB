# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikabesi/NLP_LAB/blob/main/post_tag_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("ChatGPT helps people write Python code for NLP tasks.")
print([(t.text, t.pos_) for t in doc])
# Out:
# [('ChatGPT', 'NOUN'), ('helps', 'VERB'), ('people', 'NOUN'), ('write', 'VERB'), ('Python', 'PROPN'), ('code', 'NOUN'), ('for', 'ADP'), ('NLP', 'PROPN'), ('tasks', 'NOUN'), ('.', 'PUNCT')]
