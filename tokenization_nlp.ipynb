# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikabesi/NLP_LAB/blob/main/tokenization_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")

text = "Hello there! How are you doing today? I hope you're learning NLP."
doc = nlp(text)

print("Word Tokenization:")
for token in doc:
    print(token.text)
# Out:
# Word Tokenization:
# Hello
# there
# !
# How
# are
# you
# doing
# today
# ?
# I
# hope
# you
# 're
# learning
# NLP
# .
