# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikabesi/NLP_LAB/blob/main/spell_correction_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

text = "I have a speling errror in thiss sentense."
blob = TextBlob(text)

print("Original:", text)
print("Corrected:", blob.correct())
# Out:
# Original: I have a speling errror in thiss sentense.
# Corrected: I have a spelling error in this sentence.
